# %%
# 파일 오픈
import csv
f = open('c:/sh/study/study everyday/data files/seoul.csv','r',encoding='cp949')
data = csv.reader(f, delimiter = ',')
print(data)
f.close()
# Out:
# <_csv.reader object at 0x000001A0F1C22D00>

# %%
# 파일 출력
import csv
f = open('c:/sh/study/study everyday/data files/seoul.csv','r',encoding='cp949')
data = csv.reader(f, delimiter = ',')
for i in data:
    print(i)
f.close()

# %%
# 헤더 저장.
import csv
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
header = next(data)
print(header)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
# 헤더를 저장하고 데이터만 출력하기
import csv
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
header = next(data)
for i in data:
    print(i)
f.close()

# %%
# 서울의 가장 더운 날 출력
import csv
max_temp = -999
max_date = ''
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
header = next(data)
for row in data:
    if row[-1] == '':
        row[-1] = -999
    row[-1] = float(row[-1])
    if max_temp < row[-1]:
        max_temp = row[-1]
        max_date = row[0]
f.close()
print('최고기온이 가장 높았던 날은 ',max_date,'이고 기온은',max_temp,'도 입니다.')
# Out:
# 최고기온이 가장 높았던 날은  2018-08-01 이고 기온은 39.6 도 입니다.

# %%
# 기온 변화를 그래프로 그리기
# 데이터 불러오기
import csv
result = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)

# 빈 리스트에 데이터 저장
for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
print(result)
f.close()

# %%
# 데이터 시각화
import matplotlib.pyplot as plt
plt.plot(result,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 날짜 데이터 추출하기
s = '1907-10-01'
print(s.split('-'))
print(s.split('-')[0])
print(s.split('-')[1])
print(s.split('-')[2])
# Out:
# ['1907', '10', '01']
# 1907
# 10
# 01

# %%
# 특정 데이터만 추출
import csv
result = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            result.append(float(row[-1]))
plt.plot(result,'blue')
plt.show()
f.close()

# %%
# 내 생일날 기온 변화 그래프로 그리기
import csv
max_result = [] 
min_result = []
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '28':
            max_result.append(float(row[-1]))
    if row[-2] != '' :
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '28':
            min_result.append(float(row[-2]))
plt.plot(max_result,'blue',label = 'max temp')
plt.plot(min_result,'green',label = 'min temp')
plt.legend()
plt.show()
f.close()

# %%
# 타이틀 한글로 설정
import csv
max_result = [] 
min_result = []
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '28':
            max_result.append(float(row[-1]))
    if row[-2] != '' :
        if row[0].split('-')[1] == '05' and row[0].split('-')[2] == '28':
            min_result.append(float(row[-2]))
plt.rc('font',family = 'Malgun Gothic')
plt.title('내 생일의 기온 변화',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.plot(max_result,'blue',label = 'max temp')
plt.plot(min_result,'green',label = 'min temp')
plt.legend()
plt.show()
f.close()

# %%
# 히스토그램 그리기
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.tick_params(color = 'white',colors = 'white')
plt.show()

# %%
# 히스토그램 주사위
import random
import matplotlib.pyplot as plt
dice = []
for i in range(100):
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice,bins=6)
plt.tick_params(color = 'white',colors = 'white')
plt.show()
# Out:
# [1, 4, 6, 6, 6, 3, 2, 5, 3, 1, 1, 3, 6, 5, 5, 2, 3, 3, 5, 4, 6, 2, 5, 4, 2, 2, 1, 1, 3, 3, 2, 3, 3, 3, 1, 6, 1, 6, 5, 3, 2, 2, 4, 5, 6, 3, 1, 5, 1, 6, 2, 6, 6, 6, 6, 3, 4, 2, 3, 2, 5, 4, 4, 2, 5, 4, 6, 6, 5, 1, 1, 5, 1, 5, 3, 2, 5, 3, 2, 4, 6, 6, 6, 1, 1, 2, 4, 2, 5, 6, 4, 4, 4, 5, 5, 2, 5, 6, 1, 2]

# %%
# 기온 히스토그램 그리기
import csv
import matplotlib.pyplot as plt
result = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
plt.rc('font',family = 'Malgun Gothic')
plt.title('최고기온 히스토그램',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.hist(result, bins=100,color = 'red')
plt.show()
f.close()
# Out:
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 여러 데이터에 대한 그래프
import csv
import matplotlib.pyplot as plt
aug = []
jan = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '' and month == '08':
        aug.append(float(row[-1]))
    elif row[-1] !='' and month == '01':
        jan.append(float(row[-1]))
plt.rc('font',family = 'Malgun Gothic')
plt.title('최고기온 히스토그램',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.hist(aug, bins=100,color = 'red')
plt.hist(jan, bins=100,color = 'blue')
plt.show()
f.close()

# %%
# box plot
import matplotlib.pyplot as plt
import random
result = []
for i in range(13):
    result.append(random.randint(1,1000))
plt.tick_params(color = 'white',colors = 'white')
plt.boxplot(result)
plt.show()
# Out:
# [36, 38, 46, 81, 224, 260, 280, 289, 474, 869, 873, 898, 954]

# %%
# 기온데이터 박스플랏
import csv
import matplotlib.pyplot as plt
result = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
plt.title('box plot',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.boxplot(result)
plt.show()
f.close()
# Out:
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import csv
import matplotlib.pyplot as plt
aug = []
jan = [] 
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '' and month == '08':
        aug.append(float(row[-1]))
    elif row[-1] !='' and month == '01':
        jan.append(float(row[-1]))
plt.rc('font',family = 'Malgun Gothic')
plt.title('8월과 1월의 최고기온 박스그림',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()
f.close()
# Out:
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 리스트 데이터를 사용한 박스플랏
import csv
import matplotlib.pyplot as plt
month = [[],[],[],[],[],[],[],[],[],[],[],[]]
f = open('c:/sh/study/study everyday/data files/seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
    if row[-1]!='':
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
plt.rc('font',family = 'Malgun Gothic')
plt.title('1 ~ 12월 최고기온 박스그림',color = 'white')
plt.tick_params(color = 'white',colors = 'white')
plt.boxplot(result)
plt.show()
f.close()
# Out:
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\tmdgh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
